# %%
from ast import Name
import pandas as pd

# %%
df=pd.DataFrame({"Name":["Asha","Rahul","Kiran","Sneha"],
                 "Age":[20,21,19,22],
                 "Marks":[85,78,88,92],
                 "Gender":["Female","Male","Male","Female"]})

# %%
df
# Out:
#     Name  Age  Marks  Gender
# 0   Asha   20     85  Female
# 1  Rahul   21     78    Male
# 2  Kiran   19     88    Male
# 3  Sneha   22     92  Female

# %%
df["Marks"].mean()
# Out:
# np.float64(85.75)

# %%
df["Marks"].max()
# Out:
# 92

# %%
df[df["Marks"] == df["Marks"].max()]
# Out:
#     Name  Age  Marks  Gender
# 3  Sneha   22     92  Female

# %%
import matplotlib.pyplot as plt

plt.bar(df["Name"], df["Marks"])
plt.xlabel("Students")
plt.ylabel("Marks")
plt.title("Student Marks Analysis")
plt.show()
